# %% [markdown]
# <center><font size="18"><b>Waterhack 2018</b></font></center>

# %% [markdown]
# ### Pregunta 1: ¿Existen diferencias en términos de igualdad entre comunidades?

# %%
from IPython.display import Image
Image(filename="graficos/numero_personas_genero.png")

# %%
from IPython.display import Image
Image(filename="graficos/numero_personas_genero_pueblo.png")

# %%
from IPython.display import Image
Image(filename="graficos/numero_personas_genero_cabeza.png")

# %%
from IPython.display import Image
Image(filename="graficos/numero_personas_genero_decision_maker.png")

# %% [markdown]
# ### Pregunta 2.1: ¿Quienes son los que más tiempo tardan para recoger agua?
#
# <font size=3>Para responder a esta pregunta,  </font>

# %%
from IPython.display import Image
Image(filename="graficos/media_tiempo_recogida_pueblo.png")

# %%
from IPython.display import Image
Image(filename="graficos/media_tiempo_recogida_collector.png")

# %%
from IPython.display import Image
Image(filename="graficos/heatmap_tiempo_lluvia.png")

# %%
Image(filename="graficos/heatmap_tiempo_seco.png")

# %% [markdown]
# ### Pregunta 2.2: ¿Cuánto deben cargar?

# %%
Image(filename="graficos/2.2.png")

# %% [markdown]
# ### Pregunta 3: ¿Cual es el hogar en cada comunidad más vulnerable al Cambio Climático?

# %%
Image(filename="graficos/worst_households.png")
